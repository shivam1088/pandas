# %%
import pandas as pd
data=pd.read_csv("/home/developer/Desktop/git/data/Financial-Analytics-data1.csv")
data
# Out:
#                 Name  Mar Cap - Crore  Sales Qtr - Crore Market_Cap_Category  \
# 0     Reliance Inds.        583436.72           99810.00           Large Cap
# 1                TCS        563709.84           30904.00           Large Cap
# 2          HDFC Bank        482953.59           20581.27           Large Cap
# 3                ITC        320985.27            9772.02           Large Cap
# 4            H D F C        289497.37           16840.51           Large Cap
# ..               ...              ...                ...                 ...
# 454      Prime Focus          3031.50             609.61      Very Small Cap
# 455  Lak. Vilas Bank          3029.57             790.17      Very Small Cap
# 456            NOCIL          3026.26             249.27      Very Small Cap
# 457    Orient Cement          3024.32             511.53      Very Small Cap
# 458  Natl.Fertilizer          3017.07            2840.75      Very Small Cap
#
#     Sales_Qrt_Category
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 459 entries, 0 to 458
# Data columns (total 5 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Name                 459 non-null    object
#  1   Mar Cap - Crore      459 non-null    float64
#  2   Sales Qtr - Crore    459 non-null    float64
#  3   Market_Cap_Category  459 non-null    object
#  4   Sales_Qrt_Category   459 non-null    object
# dtypes: float64(2), object(3)
# memory usage: 18.1+ KB

# %%
data.describe()
# Out:
#        Mar Cap - Crore  Sales Qtr - Crore
# count       459.000000         459.000000
# mean      28870.974139        3807.789412
# std       60557.081792        9989.449987
# min        3017.070000           0.000000
# 25%        4942.815000         534.910000
# 50%       10442.090000        1137.170000
# 75%       24707.320000        2730.195000
# max      583436.720000      110666.930000

# %%
data.max()
# Out:
# Name                   eClerx Services
# Mar Cap - Crore              583436.72
# Sales Qtr - Crore            110666.93
# Market_Cap_Category     Very Small Cap
# Sales_Qrt_Category      Very Low Sales
# dtype: object

# %%
data['Mar Cap - Crore'].apply(lambda x:x+10)
# Out:
# 0      583446.72
# 1      563719.84
# 2      482963.59
# 3      320995.27
# 4      289507.37
#          ...
# 454      3041.50
# 455      3039.57
# 456      3036.26
# 457      3034.32
# 458      3027.07
# Name: Mar Cap - Crore, Length: 459, dtype: float64

# %%
data.pivot(index='Name',columns='Market_Cap_Category')
# Out:
#                     Mar Cap - Crore                                     \
# Market_Cap_Category       Large Cap   Mid Cap Small Cap Very Small Cap
# Name
# 3M India                        NaN  23101.19       NaN            NaN
# A B B                      31983.33       NaN       NaN            NaN
# ACC                        30803.68       NaN       NaN            NaN
# AIA Engg.                       NaN  13593.35       NaN            NaN
# APL Apollo                      NaN       NaN       NaN        4775.03
# ...                             ...       ...       ...            ...
# Yes Bank                   71028.13       NaN       NaN            NaN
# Zee Entertainmen           54817.89       NaN       NaN            NaN
# Zensar Tech.                    NaN       NaN       NaN        4066.42
# Zydus Wellness                  NaN       NaN   4921.45            NaN
# eClerx Services                 NaN       NaN   5259.14            NaN
#
# ...

# %%
# data=pd.read_csv("/home/developer/Desktop/git/data/Financial-Analytics-data1.csv")
df=pd.read_csv("/home/developer/Desktop/git/data/ecom.csv")
df
# Out:
#      product_id product_name        category   price  review_score  \
# 0             1    Product_1             NaN  190.40           NaN
# 1             2          NaN             NaN     NaN           3.2
# 2             3    Product_3            Toys  367.34           4.5
# 3             4    Product_4             NaN  301.34           NaN
# 4             5    Product_5           Books   82.23           4.2
# ..          ...          ...             ...     ...           ...
# 995         996  Product_996  Home & Kitchen   50.33           3.6
# 996         997  Product_997  Home & Kitchen  459.07           4.8
# 997         998          NaN          Sports   72.73           NaN
# 998         999  Product_999             NaN  475.37           1.2
# 999        1000          NaN            Toys     NaN           2.1
#
#      review_count  sales_month_1  sales_month_2  sales_month_3  sales_month_4  \
# 0           220.0            NaN          449.0            NaN          784.0
# ...

# %%
df.head()
# Out:
#    product_id product_name category   price  review_score  review_count  \
# 0           1    Product_1      NaN  190.40           NaN         220.0
# 1           2          NaN      NaN     NaN           3.2           NaN
# 2           3    Product_3     Toys  367.34           4.5         163.0
# 3           4    Product_4      NaN  301.34           NaN         951.0
# 4           5    Product_5    Books   82.23           4.2         220.0
#
#    sales_month_1  sales_month_2  sales_month_3  sales_month_4  sales_month_5  \
# 0            NaN          449.0            NaN          784.0            NaN
# 1           21.0            NaN          861.0            NaN          524.0
# 2          348.0          558.0          567.0          143.0          771.0
# 3            NaN          678.0            NaN           15.0            NaN
# 4          682.0          451.0          649.0          301.0          620.0
#
# ...

# %%
pip install mysql-connector-python
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install pandas pymysql
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install sqlalchemy mysql-connector-python
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import sqlite3
import mysql.connector
from sqlalchemy import create_engine,text

# %%
data1 = 'mysql+mysqlconnector://root:your_password@localhost:3306/pandas_practice'
engine=create_engine(data1)
engine
# Out:
# Engine(mysql+mysqlconnector://root:***@localhost:3306/pandas_practice)

# %%
df.to_sql(name='ProductData',con=engine,if_exists='replace',index=False)
# Out:
# -1

# %%
query="select * from ProductData limit 5";

# %%
data=pd.read_sql(query,engine)
data
# Out:
#    product_id product_name category   price  review_score  review_count  \
# 0           1    Product_1     None  190.40           NaN         220.0
# 1           2         None     None     NaN           3.2           NaN
# 2           3    Product_3     Toys  367.34           4.5         163.0
# 3           4    Product_4     None  301.34           NaN         951.0
# 4           5    Product_5    Books   82.23           4.2         220.0
#
#    sales_month_1  sales_month_2  sales_month_3  sales_month_4  sales_month_5  \
# 0            NaN          449.0            NaN          784.0            NaN
# 1           21.0            NaN          861.0            NaN          524.0
# 2          348.0          558.0          567.0          143.0          771.0
# 3            NaN          678.0            NaN           15.0            NaN
# 4          682.0          451.0          649.0          301.0          620.0
#
# ...

# %%
query='''select max(price),min(price),sum(price) from ProductData''';
data=pd.read_sql(query,engine)
data
# Out:
#    max(price)  min(price)  sum(price)
# 0      499.86        7.29   246975.76

# %%
query='''select max(price),category,product_name,sales_month_1 from ProductData group by category,product_name,sales_month_1''';
data=pd.read_sql(query,engine)
data
# Out:
#      max(price)        category product_name  sales_month_1
# 0        190.40            None    Product_1            NaN
# 1           NaN            None         None           21.0
# 2        367.34            Toys    Product_3          348.0
# 3        301.34            None    Product_4            NaN
# 4         82.23           Books    Product_5          682.0
# ..          ...             ...          ...            ...
# 995       50.33  Home & Kitchen  Product_996          488.0
# 996      459.07  Home & Kitchen  Product_997           18.0
# 997       72.73          Sports         None          725.0
# 998      475.37            None  Product_999          196.0
# 999         NaN            Toys         None            NaN
#
# [1000 rows x 4 columns]

# %%
query='''select distinct price,category from ProductData where price>300 and price<400''';
data=pd.read_sql(query,engine)
data
# Out:
#       price        category
# 0    367.34            Toys
# 1    301.34            None
# 2    302.55     Electronics
# 3    355.50        Clothing
# 4    307.87        Clothing
# ..      ...             ...
# 182  300.44  Home & Kitchen
# 183  386.60          Sports
# 184  365.45           Books
# 185  345.76            Toys
# 186  348.87  Home & Kitchen
#
# [187 rows x 2 columns]

# %%
query='''select price from ProductData where price>300 and not price<400''';
data=pd.read_sql(query,engine)
data
# Out:
#       price
# 0    433.76
# 1    485.11
# 2    417.06
# 3    474.70
# 4    482.99
# ..      ...
# 198  468.73
# 199  410.46
# 200  400.71
# 201  459.07
# 202  475.37
#
# [203 rows x 1 columns]

# %%
query='''select price,category from ProductData''';
data=pd.read_sql(query,engine)
data
# Out:
#       price        category
# 0    190.40            None
# 1       NaN            None
# 2    367.34            Toys
# 3    301.34            None
# 4     82.23           Books
# ..      ...             ...
# 995   50.33  Home & Kitchen
# 996  459.07  Home & Kitchen
# 997   72.73          Sports
# 998  475.37            None
# 999     NaN            Toys
#
# [1000 rows x 2 columns]

# %%
query='''select avg(price),category from ProductData where price>400 group by category order by category desc''';
data=pd.read_sql(query,engine)
data
# Out:
#    avg(price)        category
# 0  452.465806            Toys
# 1  450.010769          Sports
# 2  449.818519  Home & Kitchen
# 3  454.213030          Health
# 4  440.789286     Electronics
# 5  446.827500        Clothing
# 6  447.731818           Books
# 7  475.370000            None

# %%
query='''select price,category from ProductData where product_name="Electronics" is null''';
data=pd.read_sql(query,engine)
data
# Out:
#    price category
# 0  72.73   Sports
# 1    NaN     Toys

# %%
df.head()
# Out:
#    product_id product_name category   price  review_score  review_count  \
# 0           1    Product_1      NaN  190.40           NaN         220.0
# 1           2          NaN      NaN     NaN           3.2           NaN
# 2           3    Product_3     Toys  367.34           4.5         163.0
# 3           4    Product_4      NaN  301.34           NaN         951.0
# 4           5    Product_5    Books   82.23           4.2         220.0
#
#    sales_month_1  sales_month_2  sales_month_3  sales_month_4  sales_month_5  \
# 0            NaN          449.0            NaN          784.0            NaN
# 1           21.0            NaN          861.0            NaN          524.0
# 2          348.0          558.0          567.0          143.0          771.0
# 3            NaN          678.0            NaN           15.0            NaN
# 4          682.0          451.0          649.0          301.0          620.0
#
# ...

# %%
query='''select * from ProductData limit 3''';
data=pd.read_sql(query,engine)
data
# Out:
#    product_id product_name category   price  review_score  review_count  \
# 0           1    Product_1     None  190.40           NaN         220.0
# 1           3    Product_3     Toys  367.34           4.5         163.0
# 2           4    Product_4     None  301.34           NaN         951.0
#
#    sales_month_1  sales_month_2  sales_month_3  sales_month_4  sales_month_5  \
# 0            NaN          449.0            NaN          784.0            NaN
# 1          348.0          558.0          567.0          143.0          771.0
# 2            NaN          678.0            NaN           15.0            NaN
#
#    sales_month_6  sales_month_7  sales_month_8  sales_month_9  sales_month_10  \
# 0          904.0          446.0            603            807             252
# 1          409.0          290.0            828            340             667
# 2          421.0          670.0            933             56             157
#
#    sales_month_11  sales_month_12
# ...

# %%
query='''select max(price) from ProductData where price<100''';
data=pd.read_sql(query,engine)
data
# Out:
#    max(price)
# 0       99.39

# %%
query='''select category from ProductData where category like "_oy%"''';
data=pd.read_sql(query,engine)
data
# Out:
#     category
# 0       Toys
# 1       Toys
# 2       Toys
# 3       Toys
# 4       Toys
# ..       ...
# 145     Toys
# 146     Toys
# 147     Toys
# 148     Toys
# 149     Toys
#
# [150 rows x 1 columns]

# %%
query="select category , price  from ProductData where category in('Toys','Books')"
data=pd.read_sql(query,engine)
data
# Out:
#     category   price
# 0       Toys  367.34
# 1      Books   82.23
# 2       Toys   82.22
# 3       Toys   15.19
# 4      Books  110.11
# ..       ...     ...
# 299     Toys  299.56
# 300    Books  365.45
# 301     Toys  345.76
# 302     Toys  400.71
# 303     Toys     NaN
#
# [304 rows x 2 columns]

# %%
query="select * from ProductData where price>400";
data=pd.read_sql(query,engine)
data
# Out:
#      product_id product_name        category   price  review_score  \
# 0             8    Product_8     Electronics  433.76           4.4
# 1            12   Product_12          Health  485.11           5.0
# 2            13   Product_13     Electronics  417.06           4.8
# 3            34   Product_34            Toys  474.70           1.5
# 4            35   Product_35        Clothing  482.99           1.3
# ..          ...          ...             ...     ...           ...
# 198         972  Product_972           Books  468.73           4.3
# 199         990  Product_990     Electronics  410.46           3.9
# 200         991  Product_991            Toys  400.71           4.1
# 201         997  Product_997  Home & Kitchen  459.07           4.8
# 202         999  Product_999            None  475.37           1.2
#
#      review_count  sales_month_1  sales_month_2  sales_month_3  sales_month_4  \
# 0           906.0          905.0           83.0           48.0          926.0
# ...

# %%
query='''select * from ProductData where price not in('Toys','Books')''';
data=pd.read_sql(query,engine)
data
# Out:
#      product_id product_name        category   price  review_score  \
# 0             1    Product_1            None  190.40           NaN
# 1             3    Product_3            Toys  367.34           4.5
# 2             4    Product_4            None  301.34           NaN
# 3             5    Product_5           Books   82.23           4.2
# 4             6    Product_6            Toys   82.22           3.6
# ..          ...          ...             ...     ...           ...
# 993         995  Product_995          Sports  183.68           4.0
# 994         996  Product_996  Home & Kitchen   50.33           3.6
# 995         997  Product_997  Home & Kitchen  459.07           4.8
# 996         998         None          Sports   72.73           NaN
# 997         999  Product_999            None  475.37           1.2
#
#      review_count  sales_month_1  sales_month_2  sales_month_3  sales_month_4  \
# 0           220.0            NaN          449.0            NaN          784.0
# ...

# %%
query='''select price,category from ProductData where price between 200 and 300''';
data=pd.read_sql(query,engine)
data
# Out:
#       price        category
# 0    264.75  Home & Kitchen
# 1    218.81           Books
# 2    230.75        Clothing
# 3    259.55            Toys
# 4    298.25           Books
# ..      ...             ...
# 189  299.56            Toys
# 190  250.70        Clothing
# 191  250.27          Sports
# 192  220.24        Clothing
# 193  297.16  Home & Kitchen
#
# [194 rows x 2 columns]

# %%
query='''select * from ProductData where price not between 200 and 300''';
data=pd.read_sql(query,engine)
data
# Out:
#      product_id product_name        category   price  review_score  \
# 0             1    Product_1            None  190.40           NaN
# 1             3    Product_3            Toys  367.34           4.5
# 2             4    Product_4            None  301.34           NaN
# 3             5    Product_5           Books   82.23           4.2
# 4             6    Product_6            Toys   82.22           3.6
# ..          ...          ...             ...     ...           ...
# 799         995  Product_995          Sports  183.68           4.0
# 800         996  Product_996  Home & Kitchen   50.33           3.6
# 801         997  Product_997  Home & Kitchen  459.07           4.8
# 802         998         None          Sports   72.73           NaN
# 803         999  Product_999            None  475.37           1.2
#
#      review_count  sales_month_1  sales_month_2  sales_month_3  sales_month_4  \
# 0           220.0            NaN          449.0            NaN          784.0
# ...

# %%
df=pd.read_csv('/home/developer/Desktop/git/data/first.csv')
df.columns
# Out:
# Index(['Unnamed: 0', 'name', 'sal', 'marks'], dtype='object')

# %%
df.pop('Unnamed: 0')
# Out:
# 0    0
# 1    1
# 2    2
# 3    3
# Name: Unnamed: 0, dtype: int64

# %%
df.columns
# Out:
# Index(['name', 'sal', 'marks'], dtype='object')

# %%
df1 = 'mysql+mysqlconnector://root:your_password@localhost:3306/pandas_practice'
engine=create_engine(df1)
engine
# Out:
# Engine(mysql+mysqlconnector://root:***@localhost:3306/pandas_practice)

# %%
df.to_sql(name='Employee',con=engine,if_exists='append',index=False)
# Out:
# -1

# %%
query='select * from Employee'
df2=pd.read_sql(query,engine)
df2
# Out:
#    id name     sal  marks
# 0   1    s  2233.0     12
# 1   2    d   344.0     34
# 2   3    f  4545.0     56
# 3   4    g    45.0     68

# %%
query ='''select * from ProductData inner join Employee as ProductData.Product_id=Employee.id''';
data=pd.read_sql(query,engine)
data
# Out:
# ---------------------------------------------------------------------------
# ProgrammingError                          Traceback (most recent call last)
# File ~/.local/lib/python3.8/site-packages/sqlalchemy/engine/base.py:1967, in Connection._exec_single_context(self, dialect, context, statement, parameters)
#    1966     if not evt_handled:
# -> 1967         self.dialect.do_execute(
#    1968             cursor, str_statement, effective_parameters, context
#    1969         )
#    1971 if self._has_events or self.engine._has_events:
#
# File ~/.local/lib/python3.8/site-packages/sqlalchemy/engine/default.py:941, in DefaultDialect.do_execute(self, cursor, statement, parameters, context)
#     940 def do_execute(self, cursor, statement, parameters, context=None):
# --> 941     cursor.execute(statement, parameters)
#
# File ~/.local/lib/python3.8/site-packages/mysql/connector/cursor.py:537, in MySQLCursor.execute(self, operation, params, multi)
#     536 try:
# ...
