# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data=pd.read_csv('/content/drive/MyDrive/Colab Notebooks/amazon_project/online.csv')

# %%
data
# Out:
#       Course_ID   Course_Name    Unnamed: 2  Duration (hours)  \
# 0           1.0      Course_1           NaN               NaN
# 1           2.0      Course_2  Office Tools              57.0
# 2           3.0           NaN           NaN               NaN
# 3           NaN      Course_4  Office Tools              69.0
# 4           5.0      Course_5    Technology              43.0
# ...         ...           ...           ...               ...
# 9995     9996.0   Course_9996            AI              87.0
# 9996     9997.0   Course_9997  Data Science              96.0
# 9997     9998.0           NaN           NaN               NaN
# 9998     9999.0   Course_9999   Programming              46.0
# 9999    10000.0  Course_10000   Programming              50.0
#
#       Enrolled_Students  Completion_Rate (%)           Platform   Price ($)  \
# 0                4217.0                  NaN                NaN         NaN
# ...

# %%
data['Course_Name'].value_counts().head(3)
# Out:
# Course_Name
# Course_1       1
# Course_6670    1
# Course_6663    1
# Name: count, dtype: int64

# %%
data['Course_Name'].value_counts().tail(3)
# Out:
# Course_Name
# Course_3338     1
# Course_3339     1
# Course_10000    1
# Name: count, dtype: int64

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 9 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Course_ID            9999 non-null   float64
#  1   Course_Name          9995 non-null   object
#  2   Unnamed: 2           9994 non-null   object
#  3   Duration (hours)     9994 non-null   float64
#  4   Enrolled_Students    9995 non-null   float64
#  5   Completion_Rate (%)  9992 non-null   float64
#  6   Platform             9994 non-null   object
#  7   Price ($)            9994 non-null   float64
#  8   Rating (out of 5)    9993 non-null   float64
# dtypes: float64(6), object(3)
# memory usage: 703.2+ KB

# %%
data['Course_ID']=data['Course_ID'].astype('float32')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 9 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Course_ID            9999 non-null   float32
#  1   Course_Name          9995 non-null   object
#  2   Unnamed: 2           9994 non-null   object
#  3   Duration (hours)     9994 non-null   float64
#  4   Enrolled_Students    9995 non-null   float64
#  5   Completion_Rate (%)  9992 non-null   float64
#  6   Platform             9994 non-null   object
#  7   Price ($)            9994 non-null   float64
#  8   Rating (out of 5)    9993 non-null   float64
# dtypes: float32(1), float64(5), object(3)
# memory usage: 664.2+ KB

# %%
data['Rating (out of 5)'] = data['Rating (out of 5)'].astype('float32')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 9 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Course_ID            9999 non-null   float32
#  1   Course_Name          9995 non-null   object
#  2   Unnamed: 2           9994 non-null   object
#  3   Duration (hours)     9994 non-null   float64
#  4   Enrolled_Students    9995 non-null   float64
#  5   Completion_Rate (%)  9992 non-null   float64
#  6   Platform             9994 non-null   object
#  7   Price ($)            9994 non-null   float64
#  8   Rating (out of 5)    9993 non-null   float32
# dtypes: float32(2), float64(4), object(3)
# memory usage: 625.1+ KB

# %%
data['Rating (out of 5)'].value_counts().head()
# Out:
# Rating (out of 5)
# 4.469516    2
# 4.921322    2
# 4.486968    2
# 4.655382    2
# 3.975148    2
# Name: count, dtype: int64

# %%
data
# Out:
#       Course_ID   Course_Name    Unnamed: 2  Duration (hours)  \
# 0           1.0      Course_1           NaN               NaN
# 1           2.0      Course_2  Office Tools              57.0
# 2           3.0           NaN           NaN               NaN
# 3           NaN      Course_4  Office Tools              69.0
# 4           5.0      Course_5    Technology              43.0
# ...         ...           ...           ...               ...
# 9995     9996.0   Course_9996            AI              87.0
# 9996     9997.0   Course_9997  Data Science              96.0
# 9997     9998.0           NaN           NaN               NaN
# 9998     9999.0   Course_9999   Programming              46.0
# 9999    10000.0  Course_10000   Programming              50.0
#
#       Enrolled_Students  Completion_Rate (%)           Platform   Price ($)  \
# 0                4217.0                  NaN                NaN         NaN
# ...

# %%
data.isnull().sum()
# Out:
# Course_ID              1
# Course_Name            5
# Unnamed: 2             6
# Duration (hours)       6
# Enrolled_Students      5
# Completion_Rate (%)    8
# Platform               6
# Price ($)              6
# Rating (out of 5)      7
# dtype: int64

# %%
data.duplicated().sum()
# Out:
# 0

# %%
dd=data.drop_duplicates(inplace=True)
dd

# %%
data
# Out:
#       Course_ID   Course_Name    Unnamed: 2  Duration (hours)  \
# 0           1.0      Course_1           NaN               NaN
# 1           2.0      Course_2  Office Tools              57.0
# 2           3.0           NaN           NaN               NaN
# 3           NaN      Course_4  Office Tools              69.0
# 4           5.0      Course_5    Technology              43.0
# ...         ...           ...           ...               ...
# 9995     9996.0   Course_9996            AI              87.0
# 9996     9997.0   Course_9997  Data Science              96.0
# 9997     9998.0           NaN           NaN               NaN
# 9998     9999.0   Course_9999   Programming              46.0
# 9999    10000.0  Course_10000   Programming              50.0
#
#       Enrolled_Students  Completion_Rate (%)           Platform   Price ($)  \
# 0                4217.0                  NaN                NaN         NaN
# ...

# %%
data.var()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/pandas/core/nanops.py in _f(*args, **kwargs)
#      84             try:
# ---> 85                 return f(*args, **kwargs)
#      86             except ValueError as e:
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/nanops.py in f(values, axis, skipna, **kwds)
#     146             else:
# --> 147                 result = alt(values, axis=axis, skipna=skipna, **kwds)
#     148
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/nanops.py in nanvar(values, axis, skipna, ddof, mask)
#    1006     # See https://en.wikipedia.org/wiki/Algorithms_for_calculating_variance
# -> 1007     avg = _ensure_numeric(values.sum(axis=axis, dtype=np.float64)) / count
#    1008     if axis is not None:
#
# ...

# %%
numerical_data=data.select_dtypes(include='number')
numerical_data.var()
# Out:
# Course_ID              8.332503e+06
# Duration (hours)       6.862395e+02
# Enrolled_Students      2.027308e+06
# Completion_Rate (%)    2.091204e+02
# Price ($)              3.035972e+03
# Rating (out of 5)      3.311880e-01
# dtype: float64

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 9 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Course_ID            9999 non-null   float32
#  1   Course_Name          9995 non-null   object
#  2   Unnamed: 2           9994 non-null   object
#  3   Duration (hours)     9994 non-null   float64
#  4   Enrolled_Students    9995 non-null   float64
#  5   Completion_Rate (%)  9992 non-null   float64
#  6   Platform             9994 non-null   object
#  7   Price ($)            9994 non-null   float64
#  8   Rating (out of 5)    9993 non-null   float32
# dtypes: float32(2), float64(4), object(3)
# memory usage: 625.1+ KB

# %%
data['Course_Name'].agg('unique')
# Out:
# array(['Course_1', 'Course_2', nan, ..., 'Course_9997', 'Course_9999',
#        'Course_10000'], dtype=object)

# %%
data['Course_ID'].aggregate('unique')
# Out:
# array([1.000e+00, 2.000e+00, 3.000e+00, ..., 9.998e+03, 9.999e+03,
#        1.000e+04], dtype=float32)

# %%
data['Rating (out of 5)'].aggregate({'Duration (hours)':'mean','Rating (out of 5)':'min','Price ($)':'max','Completion_Rate (%)':'sum'})
# Out:
# Duration (hours)           3.994161
# Rating (out of 5)          3.000026
# Price ($)                  4.999176
# Completion_Rate (%)    39913.648438
# Name: Rating (out of 5), dtype: float32

# %%
data=data.drop(['Platform'],axis=1)
data
# Out:
#       Course_ID   Course_Name    Unnamed: 2  Duration (hours)  \
# 0           1.0      Course_1           NaN               NaN
# 1           2.0      Course_2  Office Tools              57.0
# 2           3.0           NaN           NaN               NaN
# 3           NaN      Course_4  Office Tools              69.0
# 4           5.0      Course_5    Technology              43.0
# ...         ...           ...           ...               ...
# 9995     9996.0   Course_9996            AI              87.0
# 9996     9997.0   Course_9997  Data Science              96.0
# 9997     9998.0           NaN           NaN               NaN
# 9998     9999.0   Course_9999   Programming              46.0
# 9999    10000.0  Course_10000   Programming              50.0
#
#       Enrolled_Students   Price ($)  Rating (out of 5)
# 0                4217.0         NaN                NaN
# 1                4238.0  160.650991           3.829329
# ...

# %%
data
# Out:
#       Course_ID   Course_Name    Unnamed: 2  Duration (hours)  \
# 0           1.0      Course_1           NaN               NaN
# 1           2.0      Course_2  Office Tools              57.0
# 2           3.0           NaN           NaN               NaN
# 3           NaN      Course_4  Office Tools              69.0
# 4           5.0      Course_5    Technology              43.0
# ...         ...           ...           ...               ...
# 9995     9996.0   Course_9996            AI              87.0
# 9996     9997.0   Course_9997  Data Science              96.0
# 9997     9998.0           NaN           NaN               NaN
# 9998     9999.0   Course_9999   Programming              46.0
# 9999    10000.0  Course_10000   Programming              50.0
#
#       Enrolled_Students   Price ($)  Rating (out of 5)
# 0                4217.0         NaN                NaN
# 1                4238.0  160.650991           3.829329
# ...

# %%
data.dropna(how='any',inplace=True)
data
# Out:
#       Course_ID  Course_Name    Unnamed: 2  Duration (hours)  \
# 1           2.0     Course_2  Office Tools              57.0
# 4           5.0     Course_5    Technology              43.0
# 5           6.0     Course_6       Finance              66.0
# 7           8.0     Course_8        Design              21.0
# 8           9.0     Course_9   Programming              57.0
# ...         ...          ...           ...               ...
# 9992     9993.0  Course_9993  Office Tools              69.0
# 9994     9995.0  Course_9995  Data Science              89.0
# 9995     9996.0  Course_9996            AI              87.0
# 9996     9997.0  Course_9997  Data Science              96.0
# 9998     9999.0  Course_9999   Programming              46.0
#
#       Enrolled_Students   Price ($)  Rating (out of 5)
# 1                4238.0  160.650991           3.829329
# 4                4792.0   96.246696           4.921968
# 5                3792.0  127.509920           3.252284
# ...

# %%
data.isnull().sum()
# Out:
# Course_ID            0
# Course_Name          0
# Unnamed: 2           0
# Duration (hours)     0
# Enrolled_Students    0
# Price ($)            0
# Rating (out of 5)    0
# dtype: int64

# %%
data.duplicated().sum()
# Out:
# 0

# %%
data.idxmax()
# Out:
# Course_ID            9998
# Course_Name          9998
# Unnamed: 2              4
# Duration (hours)      111
# Enrolled_Students    2564
# Price ($)            8492
# Rating (out of 5)    2504
# dtype: int64

# %%
data.idxmin()
# Out:
# Course_ID               1
# Course_Name             9
# Unnamed: 2             24
# Duration (hours)      186
# Enrolled_Students    9662
# Price ($)             428
# Rating (out of 5)    4653
# dtype: int64

# %%
data.all()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-76-26234d758b7e> in <cell line: 1>()
# ----> 1 data.all()
#
# AttributeError: 'NoneType' object has no attribute 'all'

# %%
data.duplicated().sum()
# Out:
# 0

# %%
data.drop_duplicates(inplace=True)

# %%
data=data.drop_duplicates(inplace=True)
data

# %%
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-72-f4ed905113c9> in <cell line: 1>()
# ----> 1 data.duplicated().sum()
#
# AttributeError: 'NoneType' object has no attribute 'duplicated'

# %%
data
# Out:
#       Course_ID   Course_Name    Unnamed: 2  Duration (hours)  \
# 0           1.0      Course_1           NaN               NaN
# 1           2.0      Course_2  Office Tools              57.0
# 2           3.0           NaN           NaN               NaN
# 3           NaN      Course_4  Office Tools              69.0
# 4           5.0      Course_5    Technology              43.0
# ...         ...           ...           ...               ...
# 9995     9996.0   Course_9996            AI              87.0
# 9996     9997.0   Course_9997  Data Science              96.0
# 9997     9998.0           NaN           NaN               NaN
# 9998     9999.0   Course_9999   Programming              46.0
# 9999    10000.0  Course_10000   Programming              50.0
#
#       Enrolled_Students  Completion_Rate (%)           Platform   Price ($)  \
# 0                4217.0                  NaN                NaN         NaN
# ...

# %%
data.drop_duplicates(inplace=True)

# %%
data.duplicated().sum()
# Out:
# 0

# %%
data.loc[3,'Course_ID']
# Out:
# nan

# %%
data.loc[3:90:5,['Course_ID','Course_Name']]
# Out:
#     Course_ID Course_Name
# 3         NaN    Course_4
# 8         9.0    Course_9
# 13       14.0   Course_14
# 18       19.0   Course_19
# 23       24.0   Course_24
# 28       29.0   Course_29
# 33       34.0   Course_34
# 38       39.0   Course_39
# 43       44.0   Course_44
# 48       49.0   Course_49
# 53       54.0   Course_54
# 58       59.0   Course_59
# 63       64.0   Course_64
# 68       69.0   Course_69
# 73       74.0   Course_74
# 78       79.0   Course_79
# 83       84.0   Course_84
# 88       89.0   Course_89

# %%
data.iloc[0::100,[1,4]]
# Out:
#       Course_Name  Enrolled_Students
# 0        Course_1             4217.0
# 100    Course_101              259.0
# 200    Course_201             1825.0
# 300    Course_301             1845.0
# 400    Course_401             4157.0
# ...           ...                ...
# 9500  Course_9501             2967.0
# 9600  Course_9601             1185.0
# 9700  Course_9701              308.0
# 9800  Course_9801             4030.0
# 9900  Course_9901             2928.0
#
# [100 rows x 2 columns]

# %%
data.describe()
# Out:
#           Course_ID  Duration (hours)  Enrolled_Students  Completion_Rate (%)  \
# count   9999.000000       9994.000000        9995.000000          9992.000000
# mean    5000.999700         55.152191        2530.602401            75.125720
# std     2886.607524         26.196174        1423.835682            14.460996
# min        1.000000         10.000000         101.000000            50.008183
# 25%     2501.500000         32.000000        1289.000000            62.633313
# 50%     5001.000000         55.000000        2531.000000            75.163556
# 75%     7500.500000         78.000000        3764.000000            87.600302
# max    10000.000000        100.000000        5000.000000            99.994300
#
#          Price ($)  Rating (out of 5)
# count  9994.000000        9993.000000
# mean    106.376476           3.994161
# std      55.099655           0.575489
# min      10.037145           3.000026
# 25%      58.600519           3.490231
# ...

# %%
data['Price ($)'].count()
# Out:
# 9994

# %%
data.index
# Out:
# RangeIndex(start=0, stop=10000, step=1)

# %%
data.columns
# Out:
# Index(['Course_ID', 'Course_Name', 'Unnamed: 2', 'Duration (hours)',
#        'Enrolled_Students', 'Completion_Rate (%)', 'Platform', 'Price ($)',
#        'Rating (out of 5)'],
#       dtype='object')

# %%
data.shape
# Out:
# (10000, 9)

# %%
data.drop(1)
# Out:
#       Course_ID   Course_Name    Unnamed: 2  Duration (hours)  \
# 0           1.0      Course_1           NaN               NaN
# 2           3.0           NaN           NaN               NaN
# 3           NaN      Course_4  Office Tools              69.0
# 4           5.0      Course_5    Technology              43.0
# 5           6.0      Course_6       Finance              66.0
# ...         ...           ...           ...               ...
# 9995     9996.0   Course_9996            AI              87.0
# 9996     9997.0   Course_9997  Data Science              96.0
# 9997     9998.0           NaN           NaN               NaN
# 9998     9999.0   Course_9999   Programming              46.0
# 9999    10000.0  Course_10000   Programming              50.0
#
#       Enrolled_Students  Completion_Rate (%)           Platform   Price ($)  \
# 0                4217.0                  NaN                NaN         NaN
# ...

# %%
data.drop([4,5],axis=0)
# Out:
#       Course_ID   Course_Name    Unnamed: 2  Duration (hours)  \
# 0           1.0      Course_1           NaN               NaN
# 1           2.0      Course_2  Office Tools              57.0
# 2           3.0           NaN           NaN               NaN
# 3           NaN      Course_4  Office Tools              69.0
# 6           7.0           NaN           NaN               NaN
# ...         ...           ...           ...               ...
# 9995     9996.0   Course_9996            AI              87.0
# 9996     9997.0   Course_9997  Data Science              96.0
# 9997     9998.0           NaN           NaN               NaN
# 9998     9999.0   Course_9999   Programming              46.0
# 9999    10000.0  Course_10000   Programming              50.0
#
#       Enrolled_Students  Completion_Rate (%)           Platform   Price ($)  \
# 0                4217.0                  NaN                NaN         NaN
# ...

# %%
data.drop(['Course_ID','Course_Name'],axis=1)
# Out:
#         Unnamed: 2  Duration (hours)  Enrolled_Students  Completion_Rate (%)  \
# 0              NaN               NaN             4217.0                  NaN
# 1     Office Tools              57.0             4238.0            82.240240
# 2              NaN               NaN                NaN                  NaN
# 3     Office Tools              69.0             4308.0            58.664729
# 4       Technology              43.0             4792.0                  NaN
# ...            ...               ...                ...                  ...
# 9995            AI              87.0              482.0            55.407463
# 9996  Data Science              96.0             2029.0            93.093483
# 9997           NaN               NaN                NaN                  NaN
# 9998   Programming              46.0             3258.0            73.720149
# 9999   Programming              50.0              257.0                  NaN
#
# ...

# %%
data.drop(['Unnamed: 2'],axis=1)
# Out:
#       Course_ID   Course_Name  Duration (hours)  Enrolled_Students  \
# 0           1.0      Course_1               NaN             4217.0
# 1           2.0      Course_2              57.0             4238.0
# 2           3.0           NaN               NaN                NaN
# 3           NaN      Course_4              69.0             4308.0
# 4           5.0      Course_5              43.0             4792.0
# ...         ...           ...               ...                ...
# 9995     9996.0   Course_9996              87.0              482.0
# 9996     9997.0   Course_9997              96.0             2029.0
# 9997     9998.0           NaN               NaN                NaN
# 9998     9999.0   Course_9999              46.0             3258.0
# 9999    10000.0  Course_10000              50.0              257.0
#
#       Completion_Rate (%)           Platform   Price ($)  Rating (out of 5)
# 0                     NaN                NaN         NaN                NaN
# ...

# %%
data
# Out:
#       Course_ID   Course_Name    Unnamed: 2  Duration (hours)  \
# 0           1.0      Course_1           NaN               NaN
# 1           2.0      Course_2  Office Tools              57.0
# 2           3.0           NaN           NaN               NaN
# 3           NaN      Course_4  Office Tools              69.0
# 4           5.0      Course_5    Technology              43.0
# ...         ...           ...           ...               ...
# 9995     9996.0   Course_9996            AI              87.0
# 9996     9997.0   Course_9997  Data Science              96.0
# 9997     9998.0           NaN           NaN               NaN
# 9998     9999.0   Course_9999   Programming              46.0
# 9999    10000.0  Course_10000   Programming              50.0
#
#       Enrolled_Students  Completion_Rate (%)           Platform   Price ($)  \
# 0                4217.0                  NaN                NaN         NaN
# ...

# %%
data.dropna(how='any',axis=0)
# Out:
#       Course_ID  Course_Name    Unnamed: 2  Duration (hours)  \
# 1           2.0     Course_2  Office Tools              57.0
# 5           6.0     Course_6       Finance              66.0
# 7           8.0     Course_8        Design              21.0
# 8           9.0     Course_9   Programming              57.0
# 9          10.0    Course_10        Design              59.0
# ...         ...          ...           ...               ...
# 9992     9993.0  Course_9993  Office Tools              69.0
# 9994     9995.0  Course_9995  Data Science              89.0
# 9995     9996.0  Course_9996            AI              87.0
# 9996     9997.0  Course_9997  Data Science              96.0
# 9998     9999.0  Course_9999   Programming              46.0
#
#       Enrolled_Students  Completion_Rate (%)           Platform   Price ($)  \
# 1                4238.0            82.240240                edX  160.650991
# 5                3792.0            96.671900                edX  127.509920
# ...

# %%
data.to_numpy()
# Out:
# array([[2.0, 'Course_2', 'Office Tools', ..., 'edX', 160.650990907854,
#         3.82932939351993],
#        [6.0, 'Course_6', 'Finance', ..., 'edX', 127.509920158119,
#         3.25228346179595],
#        [8.0, 'Course_8', 'Design', ..., 'edX', 79.9409443326851,
#         3.08873048732615],
#        ...,
#        [9996.0, 'Course_9996', 'AI', ..., 'Udemy', 155.965331464066,
#         4.1556491570966],
#        [9997.0, 'Course_9997', 'Data Science', ..., 'Coursera',
#         151.022433710752, 4.03775461387811],
#        [9999.0, 'Course_9999', 'Programming', ..., 'edX',
#         101.143232127632, 3.82578139515069]], dtype=object)

# %%
data.drop(['Course_ID'],axis=1)
# Out:
#       Course_Name    Unnamed: 2  Duration (hours)  Enrolled_Students  \
# 1        Course_2  Office Tools              57.0             4238.0
# 5        Course_6       Finance              66.0             3792.0
# 7        Course_8        Design              21.0              964.0
# 8        Course_9   Programming              57.0             1246.0
# 9       Course_10        Design              59.0              489.0
# ...           ...           ...               ...                ...
# 9992  Course_9993  Office Tools              69.0             1609.0
# 9994  Course_9995  Data Science              89.0             1576.0
# 9995  Course_9996            AI              87.0              482.0
# 9996  Course_9997  Data Science              96.0             2029.0
# 9998  Course_9999   Programming              46.0             3258.0
#
#       Completion_Rate (%)           Platform   Price ($)  Rating (out of 5)
# ...

# %%
data.dropna(how='any',inplace=True)

# %%
data.dropna(how='all',axis=0)
# Out:
#       Course_ID  Course_Name    Unnamed: 2  Duration (hours)  \
# 1           2.0     Course_2  Office Tools              57.0
# 5           6.0     Course_6       Finance              66.0
# 7           8.0     Course_8        Design              21.0
# 8           9.0     Course_9   Programming              57.0
# 9          10.0    Course_10        Design              59.0
# ...         ...          ...           ...               ...
# 9992     9993.0  Course_9993  Office Tools              69.0
# 9994     9995.0  Course_9995  Data Science              89.0
# 9995     9996.0  Course_9996            AI              87.0
# 9996     9997.0  Course_9997  Data Science              96.0
# 9998     9999.0  Course_9999   Programming              46.0
#
#       Enrolled_Students  Completion_Rate (%)           Platform   Price ($)  \
# 1                4238.0            82.240240                edX  160.650991
# 5                3792.0            96.671900                edX  127.509920
# ...

# %%
data
# Out:
#       Course_ID  Course_Name    Unnamed: 2  Duration (hours)  \
# 1           2.0     Course_2  Office Tools              57.0
# 5           6.0     Course_6       Finance              66.0
# 7           8.0     Course_8        Design              21.0
# 8           9.0     Course_9   Programming              57.0
# 9          10.0    Course_10        Design              59.0
# ...         ...          ...           ...               ...
# 9992     9993.0  Course_9993  Office Tools              69.0
# 9994     9995.0  Course_9995  Data Science              89.0
# 9995     9996.0  Course_9996            AI              87.0
# 9996     9997.0  Course_9997  Data Science              96.0
# 9998     9999.0  Course_9999   Programming              46.0
#
#       Enrolled_Students  Completion_Rate (%)           Platform   Price ($)  \
# 1                4238.0            82.240240                edX  160.650991
# 5                3792.0            96.671900                edX  127.509920
# ...

# %%
data.fillna('000000000')
# Out:
#       Course_ID  Course_Name    Unnamed: 2  Duration (hours)  \
# 1           2.0     Course_2  Office Tools              57.0
# 5           6.0     Course_6       Finance              66.0
# 7           8.0     Course_8        Design              21.0
# 8           9.0     Course_9   Programming              57.0
# 9          10.0    Course_10        Design              59.0
# ...         ...          ...           ...               ...
# 9992     9993.0  Course_9993  Office Tools              69.0
# 9994     9995.0  Course_9995  Data Science              89.0
# 9995     9996.0  Course_9996            AI              87.0
# 9996     9997.0  Course_9997  Data Science              96.0
# 9998     9999.0  Course_9999   Programming              46.0
#
#       Enrolled_Students  Completion_Rate (%)           Platform   Price ($)  \
# 1                4238.0            82.240240                edX  160.650991
# 5                3792.0            96.671900                edX  127.509920
# ...

# %%
data=pd.read_csv('/content/drive/MyDrive/Colab Notebooks/amazon_project/online.csv')

# %%
data.dropna().sum()
# Out:
# Course_ID                                                     49974975.0
# Course_Name            Course_2Course_6Course_8Course_9Course_10Cours...
# Unnamed: 2             Office ToolsFinanceDesignProgrammingDesignFina...
# Duration (hours)                                                551029.0
# Enrolled_Students                                             25279797.0
# Completion_Rate (%)                                        750597.531123
# Platform               edXedXedXLinkedIn LearningedXedXLinkedIn Learn...
# Price ($)                                                 1062788.361713
# Rating (out of 5)                                            39904.81206
# dtype: object

# %%
data
# Out:
#       Course_ID   Course_Name    Unnamed: 2  Duration (hours)  \
# 0           1.0      Course_1           NaN               NaN
# 1           2.0      Course_2  Office Tools              57.0
# 2           3.0           NaN           NaN               NaN
# 3           NaN      Course_4  Office Tools              69.0
# 4           5.0      Course_5    Technology              43.0
# ...         ...           ...           ...               ...
# 9995     9996.0   Course_9996            AI              87.0
# 9996     9997.0   Course_9997  Data Science              96.0
# 9997     9998.0           NaN           NaN               NaN
# 9998     9999.0   Course_9999   Programming              46.0
# 9999    10000.0  Course_10000   Programming              50.0
#
#       Enrolled_Students  Completion_Rate (%)           Platform   Price ($)  \
# 0                4217.0                  NaN                NaN         NaN
# ...

# %%
data.fillna('java',limit=2,axis=1)
# Out:
#      Course_ID   Course_Name    Unnamed: 2 Duration (hours) Enrolled_Students  \
# 0          1.0      Course_1          java             java            4217.0
# 1          2.0      Course_2  Office Tools             57.0            4238.0
# 2          3.0          java          java              NaN               NaN
# 3         java      Course_4  Office Tools             69.0            4308.0
# 4          5.0      Course_5    Technology             43.0            4792.0
# ...        ...           ...           ...              ...               ...
# 9995    9996.0   Course_9996            AI             87.0             482.0
# 9996    9997.0   Course_9997  Data Science             96.0            2029.0
# 9997    9998.0          java          java              NaN               NaN
# 9998    9999.0   Course_9999   Programming             46.0            3258.0
# 9999   10000.0  Course_10000   Programming             50.0             257.0
#
# ...

# %%
data
# Out:
#       Course_ID   Course_Name    Unnamed: 2  Duration (hours)  \
# 0           1.0      Course_1           NaN               NaN
# 1           2.0      Course_2  Office Tools              57.0
# 2           3.0           NaN           NaN               NaN
# 3           NaN      Course_4  Office Tools              69.0
# 4           5.0      Course_5    Technology              43.0
# ...         ...           ...           ...               ...
# 9995     9996.0   Course_9996            AI              87.0
# 9996     9997.0   Course_9997  Data Science              96.0
# 9997     9998.0           NaN           NaN               NaN
# 9998     9999.0   Course_9999   Programming              46.0
# 9999    10000.0  Course_10000   Programming              50.0
#
#       Enrolled_Students  Completion_Rate (%)           Platform   Price ($)  \
# 0                4217.0                  NaN                NaN         NaN
# ...

# %%
data.dropna(thresh=2)
# Out:
#       Course_ID   Course_Name    Unnamed: 2  Duration (hours)  \
# 0           1.0      Course_1           NaN               NaN
# 1           2.0      Course_2  Office Tools              57.0
# 3           NaN      Course_4  Office Tools              69.0
# 4           5.0      Course_5    Technology              43.0
# 5           6.0      Course_6       Finance              66.0
# ...         ...           ...           ...               ...
# 9994     9995.0   Course_9995  Data Science              89.0
# 9995     9996.0   Course_9996            AI              87.0
# 9996     9997.0   Course_9997  Data Science              96.0
# 9998     9999.0   Course_9999   Programming              46.0
# 9999    10000.0  Course_10000   Programming              50.0
#
#       Enrolled_Students  Completion_Rate (%)           Platform   Price ($)  \
# 0                4217.0                  NaN                NaN         NaN
# ...

# %%
data.replace(3,method='ffill')
# Out:
# <ipython-input-165-27d3ce444b3b>:1: FutureWarning: The 'method' keyword in DataFrame.replace is deprecated and will be removed in a future version.
#   data.replace(3,method='ffill')
#       Course_ID   Course_Name    Unnamed: 2  Duration (hours)  \
# 0           1.0      Course_1           NaN               NaN
# 1           2.0      Course_2  Office Tools              57.0
# 2           2.0           NaN           NaN               NaN
# 3           NaN      Course_4  Office Tools              69.0
# 4           5.0      Course_5    Technology              43.0
# ...         ...           ...           ...               ...
# 9995     9996.0   Course_9996            AI              87.0
# 9996     9997.0   Course_9997  Data Science              96.0
# 9997     9998.0           NaN           NaN               NaN
# 9998     9999.0   Course_9999   Programming              46.0
# 9999    10000.0  Course_10000   Programming              50.0
#
# ...

# %%
dta=data.interpolate(method='linear',limit=5)
dta
# Out:
# <ipython-input-179-20f4cd4e7493>:1: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   dta=data.interpolate(method='linear',limit=5)
#      Course_ID   Course_Name    Unnamed: 2  Duration (hours)  \
# 0          LOW      Course_1           NaN               NaN
# 1         High      Course_2  Office Tools              57.0
# 2         High           NaN           NaN              63.0
# 3          LOW      Course_4  Office Tools              69.0
# 4         High      Course_5    Technology              43.0
# ...        ...           ...           ...               ...
# 9995      High   Course_9996            AI              87.0
# 9996      High   Course_9997  Data Science              96.0
# 9997      High           NaN           NaN              71.0
# 9998      High   Course_9999   Programming              46.0
# ...

# %%
data.interpolate(limit=3)
# Out:
# <ipython-input-180-828ce7b78041>:1: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   data.interpolate(limit=3)
#      Course_ID   Course_Name    Unnamed: 2  Duration (hours)  \
# 0          LOW      Course_1           NaN               NaN
# 1         High      Course_2  Office Tools              57.0
# 2         High           NaN           NaN              63.0
# 3          LOW      Course_4  Office Tools              69.0
# 4         High      Course_5    Technology              43.0
# ...        ...           ...           ...               ...
# 9995      High   Course_9996            AI              87.0
# 9996      High   Course_9997  Data Science              96.0
# 9997      High           NaN           NaN              71.0
# 9998      High   Course_9999   Programming              46.0
# 9999      High  Course_10000   Programming              50.0
#
# ...

# %%
data
# Out:
#      Course_ID   Course_Name    Unnamed: 2  Duration (hours)  \
# 0          LOW      Course_1           NaN               NaN
# 1         High      Course_2  Office Tools              57.0
# 2         High           NaN           NaN               NaN
# 3          LOW      Course_4  Office Tools              69.0
# 4         High      Course_5    Technology              43.0
# ...        ...           ...           ...               ...
# 9995      High   Course_9996            AI              87.0
# 9996      High   Course_9997  Data Science              96.0
# 9997      High           NaN           NaN               NaN
# 9998      High   Course_9999   Programming              46.0
# 9999      High  Course_10000   Programming              50.0
#
#       Enrolled_Students  Completion_Rate (%)           Platform   Price ($)  \
# 0                4217.0                  NaN                NaN         NaN
# 1                4238.0            82.240240                edX  160.650991
# ...

# %%
data.groupby('Course_ID').aggregate({'Course_ID':'count','Enrolled_Students':'mean'})
# Out:
#            Course_ID  Enrolled_Students
# Course_ID
# High            9998        2530.255779
# LOW                2        4262.500000

# %%
data.groupby(['Course_ID','Course_Name','Enrolled_Students']).aggregate({'Enrolled_Students':'min'})
# Out:
#                                           Enrolled_Students
# Course_ID Course_Name  Enrolled_Students
# High      Course_10    489.0                          489.0
#           Course_100   4607.0                        4607.0
#           Course_1000  346.0                          346.0
#           Course_10000 257.0                          257.0
#           Course_1001  3209.0                        3209.0
# ...                                                     ...
#           Course_9996  482.0                          482.0
#           Course_9997  2029.0                        2029.0
#           Course_9999  3258.0                        3258.0
# LOW       Course_1     4217.0                        4217.0
#           Course_4     4308.0                        4308.0
#
# [9995 rows x 1 columns]

# %%
data['Enrolled_Students'].apply(lambda x:x**2).head()
# Out:
# 0    17783089.0
# 1    17960644.0
# 2           NaN
# 3    18558864.0
# 4    22963264.0
# Name: Enrolled_Students, dtype: float64

# %%
data.pivot(axis=1)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-199-9f911e2c3698> in <cell line: 1>()
# ----> 1 data.pivot(axis=1)
#
# TypeError: DataFrame.pivot() got an unexpected keyword argument 'axis'

# %%
data.nunique()
# Out:
# Course_ID                 2
# Course_Name            9995
# Unnamed: 2                9
# Duration (hours)         91
# Enrolled_Students      4240
# Completion_Rate (%)    9992
# Platform                  4
# Price ($)              9994
# Rating (out of 5)      9993
# dtype: int64

# %%
data.notna()
# Out:
#       Course_ID  Course_Name  Unnamed: 2  Duration (hours)  Enrolled_Students  \
# 0          True         True       False             False               True
# 1          True         True        True              True               True
# 2          True        False       False             False              False
# 3          True         True        True              True               True
# 4          True         True        True              True               True
# ...         ...          ...         ...               ...                ...
# 9995       True         True        True              True               True
# 9996       True         True        True              True               True
# 9997       True        False       False             False              False
# 9998       True         True        True              True               True
# 9999       True         True        True              True               True
#
# ...

# %%
# data.pivot(index='Course_ID',columns='Course_Name')
duplicate_courses = data['Course_ID'].duplicated().any()

# %%
duplicate_courses
# Out:
# True

# %%
if duplicate_courses:
  print("Warning: Duplicate Course IDs found. Pivot operation might not be appropriate.")
else:
  data.pivot(index='Course_ID',columns='Course_Name')

# %%
data
# Out:
#      Course_ID   Course_Name    Unnamed: 2  Duration (hours)  \
# 0          LOW      Course_1           NaN               NaN
# 1         High      Course_2  Office Tools              57.0
# 2         High           NaN           NaN               NaN
# 3          LOW      Course_4  Office Tools              69.0
# 4         High      Course_5    Technology              43.0
# ...        ...           ...           ...               ...
# 9995      High   Course_9996            AI              87.0
# 9996      High   Course_9997  Data Science              96.0
# 9997      High           NaN           NaN               NaN
# 9998      High   Course_9999   Programming              46.0
# 9999      High  Course_10000   Programming              50.0
#
#       Enrolled_Students  Completion_Rate (%)           Platform   Price ($)  \
# 0                4217.0                  NaN                NaN         NaN
# 1                4238.0            82.240240                edX  160.650991
# ...

# %%
data
# Out:
#      Course_ID   Course_Name    Unnamed: 2  Duration (hours)  \
# 0          LOW      Course_1           NaN               NaN
# 1         High      Course_2  Office Tools              57.0
# 2         High           NaN           NaN               NaN
# 3          LOW      Course_4  Office Tools              69.0
# 4         High      Course_5    Technology              43.0
# ...        ...           ...           ...               ...
# 9995      High   Course_9996            AI              87.0
# 9996      High   Course_9997  Data Science              96.0
# 9997      High           NaN           NaN               NaN
# 9998      High   Course_9999   Programming              46.0
# 9999      High  Course_10000   Programming              50.0
#
#       Enrolled_Students  Completion_Rate (%)           Platform   Price ($)  \
# 0                4217.0                  NaN                NaN         NaN
# 1                4238.0            82.240240                edX  160.650991
# ...

# %%
data.pivot_table(columns='Course_ID',values='Rating (out of 5)').mean()
# Out:
# Course_ID
# High    3.994169
# LOW     3.913732
# dtype: float64

# %%
data.pivot_table(columns='Course_ID',values='Rating (out of 5)')
# Out:
# Course_ID              High       LOW
# Rating (out of 5)  3.994169  3.913732

# %%
data.duplicated().sum()
# Out:
# 4

# %%
data.pivot(columns='Course_Name',values='Enrolled_Students').mean().head()
# Out:
# Course_Name
# NaN               NaN
# Course_1       4217.0
# Course_10       489.0
# Course_100     4607.0
# Course_1000     346.0
# dtype: float64

# %%
data.pivot_table(index='Course_ID',columns='Course_Name',values='Enrolled_Students',aggfunc='sum').mean().head()
# Out:
# Course_Name
# Course_1        4217.0
# Course_10        489.0
# Course_100      4607.0
# Course_1000      346.0
# Course_10000     257.0
# dtype: float64

# %%
dd=data.melt(id_vars='Course_ID',value_vars='Enrolled_Students')
dd
# Out:
#      Course_ID           variable   value
# 0          LOW  Enrolled_Students  4217.0
# 1         High  Enrolled_Students  4238.0
# 2         High  Enrolled_Students     NaN
# 3          LOW  Enrolled_Students  4308.0
# 4         High  Enrolled_Students  4792.0
# ...        ...                ...     ...
# 9995      High  Enrolled_Students   482.0
# 9996      High  Enrolled_Students  2029.0
# 9997      High  Enrolled_Students     NaN
# 9998      High  Enrolled_Students  3258.0
# 9999      High  Enrolled_Students   257.0
#
# [10000 rows x 3 columns]

# %%
data
# Out:
#       Course_ID   Course_Name    Unnamed: 2  Duration (hours)  \
# 0           1.0      Course_1           NaN               NaN
# 1           2.0      Course_2  Office Tools              57.0
# 2           3.0           NaN           NaN               NaN
# 3           NaN      Course_4  Office Tools              69.0
# 4           5.0      Course_5    Technology              43.0
# ...         ...           ...           ...               ...
# 9995     9996.0   Course_9996            AI              87.0
# 9996     9997.0   Course_9997  Data Science              96.0
# 9997     9998.0           NaN           NaN               NaN
# 9998     9999.0   Course_9999   Programming              46.0
# 9999    10000.0  Course_10000   Programming              50.0
#
#       Enrolled_Students  Completion_Rate (%)           Platform   Price ($)  \
# 0                4217.0                  NaN                NaN         NaN
# ...

# %%
data.replace(to_replace='AI',value='python')
# Out:
#       Course_ID   Course_Name    Unnamed: 2  Duration (hours)  \
# 0           1.0      Course_1           NaN               NaN
# 1           2.0      Course_2  Office Tools              57.0
# 2           3.0           NaN           NaN               NaN
# 3           NaN      Course_4  Office Tools              69.0
# 4           5.0      Course_5    Technology              43.0
# ...         ...           ...           ...               ...
# 9995     9996.0   Course_9996        python              87.0
# 9996     9997.0   Course_9997  Data Science              96.0
# 9997     9998.0           NaN           NaN               NaN
# 9998     9999.0   Course_9999   Programming              46.0
# 9999    10000.0  Course_10000   Programming              50.0
#
#       Enrolled_Students  Completion_Rate (%)           Platform   Price ($)  \
# 0                4217.0                  NaN                NaN         NaN
# ...

# %%
plt.scatter(x=data['Enrolled_Students'],y=data['Rating (out of 5)'],color='r')
plt.title('scatter plot')
plt.xlabel('Enrolled_Students')
plt.ylabel('Rating (out of 5)')
plt.show()

# %%
sns.lineplot(x=data['Enrolled_Students'],y=data['Rating (out of 5)'],color='b')
plt.show()

# %%
plt.scatter(x=data['Course_ID'],y=data['Enrolled_Students'],color='hotpink')
plt.show()

# %%
plt.plot(data['Course_ID'],data['Enrolled_Students'])
plt.show()

# %%
plt.bar(x=data['Course_ID'],height=data['Enrolled_Students'])
plt.show()

# %%
plt.hist(x=data['Enrolled_Students'],bins=55)
plt.show()

# %%
dd=data.groupby(['Course_Name','Course_ID']).aggregate({'Enrolled_Students':['count','sum'],'Price ($)':['min','max']})
dd
# Out:
#                        Enrolled_Students           Price ($)
#                                    count     sum         min         max
# Course_Name  Course_ID
# Course_1     1.0                       1  4217.0         NaN         NaN
# Course_10    10.0                      1   489.0   82.094819   82.094819
# Course_100   100.0                     1  4607.0  166.780326  166.780326
# Course_1000  1000.0                    1   346.0  150.571668  150.571668
# Course_10000 10000.0                   1   257.0  125.116906  125.116906
# ...                                  ...     ...         ...         ...
# Course_9993  9993.0                    1  1609.0  119.713079  119.713079
# Course_9995  9995.0                    1  1576.0   59.577549   59.577549
# Course_9996  9996.0                    1   482.0  155.965331  155.965331
# Course_9997  9997.0                    1  2029.0  151.022434  151.022434
# Course_9999  9999.0                    1  3258.0  101.143232  101.143232
#
# ...

# %%
plt.boxplot(x=dd['Enrolled_Students'])
plt.show()

# %%
plt.boxplot(x=dd['Price ($)'])
plt.show()

# %%
sns.boxplot(x=data['Price ($)'])
plt.show()

# %%
#OUTLIERS

# %%
lst=[34,56,34,67,-123,3,46,73,4,8,222]
plt.boxplot(lst)
plt.show()

# %%
import numpy as np
lst=[34,56,34,67,-123,3,46,73,4,8,222]
q1=np.quantile(lst,0.25)
q3=np.quantile(lst,0.75)
q1,q3
IQR=q3-q1
IQR
lower_bound=q1-(1.5*IQR)
upper_bound=q3+(1.5*IQR)
lower_bound,upper_bound
# Out:
# (-77.25, 144.75)

# %%
outliers=[]
for i in lst:
  if i<lower_bound or i>upper_bound:
    outliers.append(i)
outliers
# Out:
# [-123, 222]

# %%
l1=[]
for i in lst:
  if i>lower_bound and i<upper_bound:
    l1.append(i)
l1
# Out:
# [34, 56, 34, 67, 3, 46, 73, 4, 8]

# %%
import matplotlib.pyplot as plt
plt.boxplot(l1)
plt.show()

# %%
import os
os.getcwd()
# Out:
# '/content'

# %%
import pandas as pd
data=pd.read_csv('/home/developer/Downloads/amzon (2).ipynb')
# Out:
# ---------------------------------------------------------------------------
# ParserError                               Traceback (most recent call last)
# Cell In[6], line 2
#       1 import pandas as pd
# ----> 2 data=pd.read_csv('/home/developer/Downloads/amzon (2).ipynb')
#
# File ~/.local/lib/python3.8/site-packages/pandas/io/parsers/readers.py:912, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
# ...

# %%
data
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 data
#
# NameError: name 'data' is not defined

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1133 entries, 0 to 1132
# Data columns (total 6 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   date         1133 non-null   object
#  1   datetime     1133 non-null   object
#  2   cash_type    1133 non-null   object
#  3   card         1044 non-null   object
#  4   money        1133 non-null   float64
#  5   coffee_name  1133 non-null   object
# dtypes: float64(1), object(5)
# memory usage: 53.2+ KB

# %%
data['money']=data['money'].astype('float32')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1133 entries, 0 to 1132
# Data columns (total 6 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   date         1133 non-null   object
#  1   datetime     1133 non-null   object
#  2   cash_type    1133 non-null   object
#  3   card         1044 non-null   object
#  4   money        1133 non-null   float32
#  5   coffee_name  1133 non-null   object
# dtypes: float32(1), object(5)
# memory usage: 48.8+ KB

# %%
data.isnull().sum()
# Out:
# date            0
# datetime        0
# cash_type       0
# card           89
# money           0
# coffee_name     0
# dtype: int64

# %%
data.duplicated().sum()
# Out:
# 0

# %%
data.fillna(method='ffill',inplace=True)
# Out:
# <ipython-input-30-a0cc4a31051a>:1: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   data.fillna(method='ffill',inplace=True)

# %%
data.isnull().sum()
# Out:
# date           0
# datetime       0
# cash_type      0
# card           0
# money          0
# coffee_name    0
# dtype: int64

# %%
data['datetime']=pd.to_datetime(data['datetime'])

# %%
data['week']=data['datetime'].to_period('W')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-44-84b361f1f1fe> in <cell line: 1>()
# ----> 1 data['week']=data['datetime'].to_period('W')
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/series.py in to_period(self, freq, copy)
#    5718         """
#    5719         if not isinstance(self.index, DatetimeIndex):
# -> 5720             raise TypeError(f"unsupported Type {type(self.index).__name__}")
#    5721
#    5722         new_obj = self.copy(deep=copy and not using_copy_on_write())
#
# TypeError: unsupported Type RangeIndex
